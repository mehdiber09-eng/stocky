# %% [markdown]
# # Stockout Trainer — Kaggle Template
#
# Ce notebook exécute le script d'entraînement inclus dans le dépôt.
# Placez les fichiers M5 dans un dataset Kaggle puis montez-le ici (par ex. /kaggle/input/m5-forecasting-accuracy).
#
# 1. Installer dépendances :
# ```
# !pip install xgboost scikit-learn pandas numpy joblib
# ```
#
# 2. Lancer entraînement sur M5 (ex. dataset monté sous /kaggle/input/m5-forecasting-accuracy) :
# ```
# !python -m app.scripts.train_model --products 300 --days 365 --dataset /kaggle/input/m5-forecasting-accuracy --dataset-format m5
# ```
#
# Exécutez "Run all" (Kernel -> Restart & Run All) pour lancer l'installation et l'entraînement.

# %%
# !pip install xgboost scikit-learn pandas numpy joblib

# %%
# Exemple : exécuter l'entraînement sur M5 (dossier /kaggle/input/m5-forecasting-accuracy)
# !python -m app.scripts.train_model --products 300 --days 365 --dataset /kaggle/input/m5-forecasting-accuracy --dataset-format m5

# %%
# Après exécution, les artefacts seront dans app/models_artifacts/
# !ls -la app/models_artifacts || true
